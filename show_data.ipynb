# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.plotly as py
import plotly.graph_objs as go
import plotly.figure_factory as ff
import seaborn as sns
import pygal
import subprocess
import shlex

# %%
loans = pd.read_csv("./loans_data.csv")
safe_loans = loans[loans.safe_loans == 1]
unsafe_loans = loans[loans.safe_loans == -1]
sns.set(color_codes=True)
print(loans)
#table = ff.create_table(loans)
#py.iplot(table, filename='loans_table')
# Out:
#        safe_loans grade  sub_grade_num  short_emp  emp_length_num  \
# 0               1     B            0.6          0              11
# 1               1     B            0.2          0               3
# 2               1     B            0.6          1               1
# 3               1     A            0.8          0               6
# 4               1     C            1.0          0               8
# 5               1     B            0.4          0              11
# 6               1     B            0.8          0               2
# 7               1     A            0.4          0               6
# 8               1     B            0.2          0               2
# 9               1     B            0.4          0               3
# 10              1     B            0.4          0               8
# 11              1     C            0.4          0               5
# 12              1     C            0.6          0               3
# ...

# %%
for i in list(loans):
    if str(loans[i][0]).replace('.','',1).isdigit() == False:
        count = loans[i].value_counts()
        np_index = np.array(count.index)
        plt.xticks(np.arange(len(np_index)), np_index)
        plt.yticks(count.values)
        #p1 = plt.bar(ind, menMeans, width, color='#d62728', yerr=menStd)
        #p2 = plt.bar(ind, womenMeans, width,bottom=menMeans, yerr=womenStd)
        #plt.legend((p1[0], p2[0]), ('Men', 'Women'))
        plt.show()
    else:
        sns.distplot(loans[i])

# %%
all = sns.pairplot(loans, hue="safe_loans", dropna=True)

# %%
safe = sns.pairplot(loans[loans.safe_loans == 1], hue="safe_loans", dropna=True)
unsafe = sns.pairplot(loans[loans.safe_loans == -1], hue="safe_loans", dropna=True)

# %%
loans.std()
# Out:
# safe_loans                   1.000001
# sub_grade_num                0.279052
# short_emp                    0.334252
# emp_length_num               3.753610
# dti                          7.619349
# payment_inc_ratio            4.262404
# delinq_2yrs                  0.688051
# delinq_2yrs_zero             0.354261
# inq_last_6mths               1.336696
# last_delinq_none             0.493112
# last_major_derog_none        0.333749
# open_acc                     4.752280
# pub_rec                      0.351779
# pub_rec_zero                 0.287099
# revol_util                  25.489055
# total_rec_late_fee           7.079199
# int_rate                     4.461684
# total_rec_int             1867.477905
# annual_inc               60955.499983
# funded_amnt               8055.659578
# funded_amnt_inv           8122.581831
# installment                242.312659
# dtype: float64

# %%
N = 5
menMeans = (20, 35, 30, 35, 27)
womenMeans = (25, 32, 34, 20, 25)
menStd = (2, 3, 4, 1, 2)
womenStd = (3, 5, 2, 3, 3)
ind = np.arange(N)    # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence

p1 = plt.bar(ind, menMeans, width, color='#d62728', yerr=menStd)
p2 = plt.bar(ind, womenMeans, width,
             bottom=menMeans, yerr=womenStd)

plt.ylabel('Scores')
plt.title('Scores by group and gender')
plt.xticks(ind, ('G1', 'G2', 'G3', 'G4', 'G5'))
plt.yticks(np.arange(0, 81, 10))
plt.legend((p1[0], p2[0]), ('Men', 'Women'))

plt.show()
